# %%
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import string
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Tweets.csv')
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
for i in df['airline'].unique():
    print(i)
    print(df[df["airline"] == i].airline_sentiment.value_counts())
    print('\n')
# Out:
# Virgin America
# negative    181
# neutral     171
# positive    152
# Name: airline_sentiment, dtype: int64
#
#
# United
# negative    2633
# neutral      697
# positive     492
# Name: airline_sentiment, dtype: int64
#
#
# Southwest
# negative    1186
# neutral      664
# positive     570
# Name: airline_sentiment, dtype: int64
#
#
# Delta
# negative    955
# neutral     723
# positive    544
# Name: airline_sentiment, dtype: int64
#
#
# US Airways
# negative    2263
# neutral      381
# positive     269
# Name: airline_sentiment, dtype: int64
#
#
# American
# negative    1960
# neutral      463
# positive     336
# Name: airline_sentiment, dtype: int64

# %% [markdown]
# Based on the output above i create a new dataframe for Southwest only. The data seems to have an issue because tweets classified as Delta are addressing JetBlue. For that reason i chose not to use the Delta subset. Virgin America has a good distribution, but also has a very limited number of tweets. For these reasons i chose Southwest as this subset has the least skewed distribution of positive/negative/neutral tweets (after Virgin America and Delta/JetBlue) while still having a resonable number of tweets. Tweets were also re-indexed starting at 0.

# %%
single_airline = pd.DataFrame(df[df['airline'] == 'Southwest'])
single_airline.reset_index(drop=True, inplace=True)
single_airline.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570309156290367488          negative                        1.0000
# 1  570309145276125185          negative                        0.6361
# 2  570307615189835777          negative                        1.0000
# 3  570306086475075585           neutral                        0.6443
# 4  570305647759265793          negative                        1.0000
#
#            negativereason  negativereason_confidence    airline  \
# 0               longlines                     0.6624  Southwest
# 1        Cancelled Flight                     0.6361  Southwest
# 2  Customer Service Issue                     1.0000  Southwest
# 3                     NaN                        NaN  Southwest
# 4  Customer Service Issue                     1.0000  Southwest
#
#   airline_sentiment_gold            name negativereason_gold  retweet_count  \
# 0                    NaN     thisradlove                 NaN              0
# 1                    NaN       tomcblock                 NaN              0
# 2                    NaN  cindyjwhitaker                 NaN              0
# 3                    NaN    liveseasoned                 NaN              0
# 4                    NaN  cindyjwhitaker                 NaN              0
#
#                                                 text tweet_coord  \
# 0    @SouthwestAir still waiting. Just hit one hour.         NaN
# 1  @SouthwestAir although I'm not happy you Cance...         NaN
# 2  @SouthwestAir Hello - been on hold for extreme...         NaN
# 3  @SouthwestAir I'm teaching new #travelers how ...         NaN
# 4  @SouthwestAir Very frustrated for the loooooon...         NaN
#
#                tweet_created            tweet_location  \
# 0  2015-02-24 11:47:53 -0800   Today I'm in: Maryland
# 1  2015-02-24 11:47:50 -0800  ÜT: 38.965477,-77.428287
# 2  2015-02-24 11:41:45 -0800                       NaN
# 3  2015-02-24 11:35:41 -0800                       NaN
# 4  2015-02-24 11:33:56 -0800                       NaN
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Eastern Time (US & Canada)
# 2  Central Time (US & Canada)
# 3                         NaN
# 4  Central Time (US & Canada)

# %% [markdown]
# Here i check for missing data and i can see there are no null values.

# %%
single_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2420 entries, 0 to 2419
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      2420 non-null   int64
#  1   airline_sentiment             2420 non-null   object
#  2   airline_sentiment_confidence  2420 non-null   float64
#  3   negativereason                1186 non-null   object
#  4   negativereason_confidence     1445 non-null   float64
#  5   airline                       2420 non-null   object
#  6   airline_sentiment_gold        8 non-null      object
#  7   name                          2420 non-null   object
#  8   negativereason_gold           5 non-null      object
#  9   retweet_count                 2420 non-null   int64
#  10  text                          2420 non-null   object
#  11  tweet_coord                   160 non-null    object
#  12  tweet_created                 2420 non-null   object
#  13  tweet_location                1596 non-null   object
#  14  user_timezone                 1659 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 283.7+ KB

# %% [markdown]
# Here i am just doing a check to see that i have the correct subset before proceeding.

# %%
single_airline['text']
# Out:
# 0         @SouthwestAir still waiting. Just hit one hour.
# 1       @SouthwestAir although I'm not happy you Cance...
# 2       @SouthwestAir Hello - been on hold for extreme...
# 3       @SouthwestAir I'm teaching new #travelers how ...
# 4       @SouthwestAir Very frustrated for the loooooon...
#                               ...
# 2415    @SouthwestAir won't answer their phones #Horri...
# 2416    @SouthwestAir We have been stuck in SJU for se...
# 2417               @SouthwestAir nice work on the update!
# 2418    @SouthwestAir you guys there? Are we on hour 2...
# 2419    @SouthwestAir its cool that my bags take a bit...
# Name: text, Length: 2420, dtype: object

# %% [markdown]
# It is clear the data still needs to be cleaned. i opted to do this manually as it was still fairly simple and it can be hard to speak to exactly what is happening when utilizing the tools available for data cleaning. The code below iterates through each tweet in the data set. First i use regex to remove retweets, http links, bitly links, and emojis, digits, stop words and such words has length less than 3. These items need to be removed as some are completely unique (links), and retweets could generate duplicate data when stripped down to text. Emojis were removed as it can be hard to understand intention.
#
# This resource was used to aid in removing emojis: https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python
#
# Next, the string is split into individual words, then all punctuation and special characters are removed. Following that, all characters are converted to lowercase. Finally, the words are joined back into a string.
#
# The following resource was used to help figure out how: https://machinelearningmastery.com/clean-text-machine-learning-python/

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=stopwords.words('english')

table = str.maketrans('', '', string.punctuation)

#remove emojis
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

for i, value in single_airline['text'].items():
    value = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', value)  # remove re-tweet
    value = re.sub("@[A-Za-z0-9_]+","", value)
    value = re.sub(r'http\S+', '', value)   # remove http links
    value = re.sub(r'bit.ly/\S+', '', value)  # remove bitly links
    value=re.sub('[^a-zA-Z]',' ',value) #remove any character that IS NOT a-z OR A-Z
    value = emoji_pattern.sub(r'', value)
    value = value.split()
    value =  ["" if t.isdigit() else t for t in value] #remove digits
    value = [w for w in value if not w in stop_words]
    value = [w.translate(table) for w in value]
    value = [w.lower() for w in value]
    single_airline['text'][i] = ' '.join(word for word in value if len(word) > 2) #keep words of length greater than 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
X = single_airline.text

# %% [markdown]
# Print the cleaned tweets to see if they have been cleaned properly. This isn't diffcult, but i leaned on the following resource for many of the following steps:
#
# https://twitterdev.github.io/do_more_with_twitter_data/clustering-users.html
#
# This is a developer resource directly from twitter.

# %%
for i, value in enumerate(X):
    print(i,': ', value.replace('\n',' '))
# Out:
# 0 :  still waiting just hit one hour
# 1 :  although happy cancelled flighted flight home tomorrow phx atl dca happy easy rebook
# 2 :  hello hold extremely long time have confirmation amp get boarding pass have tried numerous times
# 3 :  teaching new travelers research budget amp save trip today
# 4 :  very frustrated loooooong wait time speak live person cannot get boarding pass flight tomorrow
# 5 :  still update text amp still response email feel like losing customer service care
# 6 :  agents ones rude unhelpful prompted initial tweet this easy fix
# 7 :  wife group prev flight got bumped reason alone two kids least put group
# 8 :  flight delayed hrs months pregnant amp supposed caring mom whose surgery very upset
# 9 :  thank much completely made things right
# 10 :  love always get best deals
# 11 :  follow send info
# 12 :  been hold min far trying book seat infant price increased meantime what
# 13 :  glassdoor best places work snagging overall notsurprising luvthem
# 14 :  poor performance around paid express checkin weeks ago even leverage bullshit
# 15 :  thx make right help meagan fouty brancato dfw gate preboard kids group please please
# 16 :  update emergency landing jacksonville right parentsonboard
# 17 :  hold minutes please help
# 18 :  develop ding chrome firefox browser extension that would swell
# 19 :  take midway chicago march april can make get year round flypbi
# 20 :  logically would think check people board could drove home time waiting
# 21 :  thanks southwest saving trip sweetheart going miss seeing altonbrownlive thanks sohappy
# 22 :  someone call back hold two times today min still gotten
# 23 :  know suicide second leading cause death among teens
# 24 :  never mind moved flight tomorrow thanks help
# 25 :  needs wheelchair gate sure what options
# 26 :  managed get sorted phone good luck dealing snow texas
# 27 :  grounded flights equipment problems amp rude wife traveling alone young kids never
# 28 :  promise unfollow
# 29 :  just dmed confirmation number
# 30 :  look delayed flight additional half hour arriving officially five hours planned
# 31 :  weather system outage hopefully everything goes smoothly thank follow
# 32 :  belt issues been rough day worst part traveling month old wait outside degree
# 33 :  atlanta
# 34 :  moved flight main concern luggage arriving they told
# 35 :  used always fly southwest
# 36 :  got bags hours late flightr offer pick taxi costs one way spent inconvenience
# 37 :  thx expecting credit leg
# 38 :  sure please follow
# 39 :  appreciate getting gate issue figured grr plenty open gates yet sit wait tarmac
# 40 :  sent
# 41 :  minutes hold waiting ridiculous
# 42 :  seen messages past hour
# 43 :  following
# 44 :  thank you awesome flights sweetheart got screwed managed scramble get plane today
# 45 :  thanks much
# 46 :  round trip tickets arrived auction post masters invitational thanks southwest
# 47 :  went purchase flight began processing even minutes earlier points gone help
# 48 :  upset luggage damaged rude employee laguardia airport help
# 49 :  stream means get spend flight watching women world cup finals throwback bestflightever
# 50 :  status bag check area ffl
# 51 :  least enjoy free cocktail two
# 52 :  agree one airline fly away favorite dia newsbusiness
# 53 :  flight matters hell next get luggage properly transferred facepalm smh
# 54 :  phone service sucks
# 55 :  flight bwi delayed miss flight denver way find hold plane
# 56 :  airport snow removal method keep good work folks cessna become
# 57 :  people exit row still supposed give verbal approvals never asked flight
# 58 :  arrival delayed nearly hours yeah entire day airport idea stress less vacation fail
# 59 :  company caused lose entire day vacation cancun boarded waiting another plane
# 60 :  trying change reservation hold minutes online directed call help
# 61 :  first call got dropped waited mins second ran time will try late flightr way online
# 62 :  trying make change reservation whenever select flight says unable price please help
# 63 :  great boarding perfectly plane shot fml plans screwed thanks nothing
# 64 :  teyana taylor performing medusafridays free till themenofbusiness
# 65 :  let plane toilets done even work there goes family vacay playa del carmen mexico neveragain
# 66 :  thanks apology unfortunately one many bad experiences longer flying southwest
# 67 :  told customer service customer relations extend expiration date unused travel funds
# 68 :  two hours ugh get vouchers inexcusable esp pre flight check
# 69 :  flight birmingham tomorrow night can reschedule earlier flight expected snow
# 70 :  you follow back
# 71 :  horrible experience passenger size seat offered voucher christine
# 72 :  time flying southwest two years have another trip back october
# 73 :  yes much looking forward using airlines future flights never
# 74 :  need learn treat people respect little dignity fail
# 75 :  redeem points packages magically gone time finally got felt like baitandswitch
# 76 :  done
# 77 :  think get faster response twitter call
# 78 :  any idea winter advisory posted atl tomorrow rather get phl tonight
# 79 :  watch staff check passenger list twice first time forgot look ids brutal
# 80 :  flight chi buf last night almost hour delay cuz someone got plane without pass sounds safe
# 81 :  thx quick response action make good use voucher satisfied happycustomer
# 82 :  nothing help restore barely expired rapidrewards points
# 83 :  rapid rewards program sold short lasttweetaboutthis still disappointed
# 84 :  freezing plane
# 85 :  airline people screwed boarding passes way back puerto vallarta this horrible
# 86 :  groupa group never got sit next south west flight even honey moon
# 87 :  flight atlanta getting cancelled flightled schedule phone hours rep bumping
# 88 :  due apparent water issue checked fine checks husband already deal first
# 89 :  lot pissed hungry tired people stuck midway hours scheduled departure this inexcusable
# 90 :  know lost baggage portal work mobile
# 91 :  going charge wifi solid make sure take length flight open page
# 92 :  website reverted flight minute delay but changed reliable information
# 93 :  swa helps hotel industry always book flights day need somewhere swa consistent cancelled flights delays
# 94 :  unfortunately call answered service horrid swa role model finger pointing amp excuses disappointed
# 95 :  barzegar charges tourists euros night stay tent village runs
# 96 :  please make sense companion promo how set
# 97 :  unfortunately even phone died chance grab oma san
# 98 :  live atlanta cant enroll atlanta companion promotion error every time can help also sent email thanks
# 99 :  frustrating indeed especially one knows issue
# 100 :  hold customer service may quicker rebooked trip lower fare where difference
# 101 :  that chantilly paris france
# 102 :  thx responding
# 103 :  booked flight phone never got confirmation email how would getting
# 104 :  supposed take almost hours ago vacationfail frozenwater gettingimpatient theycouldatleastofferfreebooze
# 105 :  come getting points buy rapid reward shopping site
# 106 :  hey flying tampa denver today want know seats like
# 107 :  carol thrower passengers fort lauderdale airport
# 108 :  mins answer wife baby need get flight she arrived hrs prior please help venetia crook
# 109 :  wife month old might miss flight next direct mother law hold customer support
# 110 :  flight fll atl wife traveling infant line check baggage people long due computer system crash
# 111 :  thanks sent let know oyu need additional information
# 112 :  hey friends when phone list number ivr hangs multiple times not sure proceed
# 113 :  strives customer centric everything communications advertising customer journey etc anamarketers
# 114 :  always traffic insane one issue flight
# 115 :  insane traffic trying call schedule flight phone minutes nothing
# 116 :  airline trouble amp getting satisfactory customer service contact negotiate resolutions you
# 117 :  hey southwest help find flight nashville washington raleigh march please
# 118 :  why longer change trips companion online been years get message done online
# 119 :  adding number stay hard won take number checkin marriott phone helpful
# 120 :  nor fly toronto you killing smalls
# 121 :  thank
# 122 :  traditionally used sledge hammer low taking share driving scalpel approach data science anamarketers
# 123 :  customer centricity knowing people anamarketers
# 124 :  used guys travels last experience never use southwest worstcustomerservice
# 125 :  america largest airline passengers carried wonder customer service bible anamarketers
# 126 :  vipliveinthevieyard first time tried redeem pts anything really well disappointed
# 127 :  thank hope
# 128 :  way receive refund trip cancelled flight online instead calling your phone lines super busy
# 129 :  moms careers day trip intuitlife leanin southwestairlines
# 130 :  resource check delays cancelled flightlations love field flying tomorrow stressed weather
# 131 :  switching planes due mechanical problems how reboarding work was end long line stuck middle
# 132 :  why booked via phone calling list preferred kta get added ticket must use web
# 133 :  tried vip live the vineyard site went time got redeem pts packages gone
# 134 :  oscar worthy entrance
# 135 :  best airline hands amazing customer service bags free affordable flights happycamper
# 136 :  thanks ella mae las counter going beyond help get back abq flight cancelled flightled
# 137 :  will flight arrives penguin plane
# 138 :  thank taking good care people als
# 139 :  smoooothest flight attendants southwestsmoothie
# 140 :  southwest airline cancelled flight flights charleston was flight cancelled flightation really weather relate flightd
# 141 :  stepup makeitright best money hungry wewillsee
# 142 :  thanks text exactly timely data throughout issues today maybe
# 143 :  called rep pleasant less helpful told sol train consistent
# 144 :  year customer lost inches really hurt every time person front shifts raps knees
# 145 :  less pts helped had partnerrewards incoming fast enough keep pts expiring
# 146 :  wife pts expired days ago planning flight booking problems trip today anything tight budget
# 147 :  would great atleast next husband flying reservation
# 148 :  customer relations still open texas
# 149 :  thank tip
# 150 :  hate evolved seating knees seat pocket
# 151 :  thanks team dealing flight houston
# 152 :  bumped preboard flights fat whatever reason thanks
# 153 :  heart southwest commercials aimed satisfy nano smattering travelers destinations
# 154 :  urgently need two receipts sent closed can help
# 155 :  sent
# 156 :  any etd swa phl appears delayed info available gate
# 157 :  tell cancelled flightled flight delay
# 158 :  bday yesterday girl gave birth first born get courtesy flight change lynn thanks
# 159 :  know
# 160 :  need know status cancelled flightled instead delaying flight
# 161 :  weather and time cancelled flighted meeting today
# 162 :  flight empty rude
# 163 :  left ipad seat pocket filed lost item report received exactly week late flightr record unbelievable
# 164 :  flight msp cancelled flighted
# 165 :  luv please stop overheating planes second flight row feels like sauna
# 166 :  one traveling asking sister waiting nephew midland flight eventually landed
# 167 :  anyone help upgrade buisness select cant seem get hail right area know guys good
# 168 :  asked lindsey call instead like schoolgirl far call getting tired typing little notes
# 169 :  give clever advertising bagsflyfree badpolicy allows cheatcustomers
# 170 :  principle hard get mugged amp upset took money amp give anything wrongiswrong
# 171 :  customer service use words wasted time took money badbussiness theft
# 172 :  three hour flight orlando wifi uncool firstworldproblems
# 173 :  loving new planes lighting wish windows larger
# 174 :  would like ask bags picked pit amp taken hotel airport will someone contact
# 175 :  customer service fll bwi pit terrible one knows bags job clothes amp gear
# 176 :  after multiple attempts finally able submit late flight last night
# 177 :  arrive find already cancelled flighted options miss meeting you might know show
# 178 :  new day new chance right thing never late flight honest
# 179 :  darn bought wrong device way switch sure
# 180 :  quick question bought wifi phone buy tablet hours left trip
# 181 :  cool shot moon one fleet
# 182 :  hello swa who poc partnerships nonprofit organizations bwi area
# 183 :  hey remember time lost husbands bags filmjobnoequipment nowarmclothes
# 184 :  looking forward flying swa friday the luv airline dtw mdw tus
# 185 :  love airline much thanks much the service great the snacks amazing everything outstanding thanks
# 186 :  need redeem lost respect tonight lostbags filmjobnoequipment
# 187 :  way fuck lose bags husband warm clothes equipment youdidit notcool
# 188 :  assigned seating cousin amp probably sit together flight tomorrow thanks
# 189 :  wifi stays connected lifetime higgs boson
# 190 :  forget wedding fairs how discounts nonprofits donate part worth every single day
# 191 :  when phone agents able give correct departure times cun when checkin online international
# 192 :  making miss thebachelor right wah
# 193 :  please lower plane flight like bucks thanks floridavacation
# 194 :  great flight cabo last week family smoothflight frequentflyer
# 195 :  let bags flutter charge travelers change dates fullprice let travel
# 196 :  late flightst makes happy flying days bethonors
# 197 :  the fact that see black history month months year honorable will economic base for corp like future
# 198 :  offer cdn border towns incentive fly since exchange rates hurt customerappreciation gaincustomers keepem
# 199 :  what awesome flight dallas virgin america refused child peanut allergy guys thanks
# 200 :  let send follow lovedflyingwiththem notanymore wrong badpolicy
# 201 :  reference
# 202 :  welcome thoughts nearly entire plane
# 203 :  know reason flight dallas midland diverted lubbock was suppose direct midland
# 204 :  flight wifi wifi calling makes best combination who love texting feet air
# 205 :  become like every airline crooked believe taking shouldwearmasks shocked
# 206 :  conf neqm flight delayed hours friend waited bday please follow
# 207 :  twitter cust svc rule dont say fell short told cant solve problem say anything
# 208 :  disappointed service received checked online checked flight status online checked the airport
# 209 :  great day air
# 210 :  thanks
# 211 :  thanks two smooth safe fast flights boston houston luvswa
# 212 :  really love customer service lou ann phx rocks thanks ourguest
# 213 :  see atl congrats destinationdragons winners ready atlanta
# 214 :  enrolled atl companion pass offer booked flights already may start using pass
# 215 :  disappointed customer service right definitely feeling luv worse time winter
# 216 :  follow back info
# 217 :  katie gate denver international fantastic customer service helping new flyers thx amazing staff
# 218 :  kudos bag handler dtw gate ran keep bags hitting ground degree temp
# 219 :  crew flight awesome tell sent tweet maybe give free wifi canthurtasking
# 220 :  thankyou
# 221 :  much wifi fam
# 222 :  tried okay
# 223 :  happy enter sweepstakes nutsaboutsouthwest
# 224 :  thanks great customer service today
# 225 :  vinyl part prize
# 226 :  beyond ready
# 227 :  called told bag made phl still delivered call delivery service
# 228 :  looks like brooding skies ont evening
# 229 :  monkey business luv swa mdw mci homeandreadyfornexttrip
# 230 :  favorite airlines never issues plus crew entertaining
# 231 :  should way give voice customers pay services satisfactorily delivered justsayin
# 232 :  flight attendants really funny the sass giving life
# 233 :  genuinely surprised upgrade people cancelled flight flights least put comparable spot
# 234 :  following thank
# 235 :  would someone please customer relations number the website customer service
# 236 :  this second time row received text updates flight time change don offer use
# 237 :  cancelled flightled flight back queue want charge business class stay classy
# 238 :  hope flyers get credit sort delays cancelled flightlations shittydeal notimpressed
# 239 :  taylor gotta love swa responsiveness least huh
# 240 :  good thanks
# 241 :  thank
# 242 :  now love after taking money taking halfway home sorry too late flight
# 243 :  good looking forward escaping cold bit thanks
# 244 :  wifi slow what point one get internet ugh
# 245 :  questions flying maltese puppy can
# 246 :  word customer relations department open back
# 247 :  tell flight mdw fll tomorrow full capacity hoping little bit extra room
# 248 :  just left friday
# 249 :  worries just never seen today mean great card
# 250 :  thank thank thank last attempt win destinationdragons tickets success could happier
# 251 :  flight phx lax wheels stop glad home thanks professionals front cabin
# 252 :  eyes next steps improving inflight wifi runway girl
# 253 :  could maybe hook imagine dragon tickets tonight shes hugeeeee fan amp would really love
# 254 :  evennotified theflight isdelayed via email text phone call wererunning late flight would pissed unreliable
# 255 :  tweet weekend bad weather closes customer relations center process refunds cancelled flighted flights
# 256 :  stop cancelled flighting flight history tests take chemistry things learn understand
# 257 :  mdw san flt attendant melissa awesome fast smiling great after weather cancelled flight day welcome
# 258 :  area pic taken see albums
# 259 :  enjoyed call good friend flight booking problems flights elsewhere tweet one time tell many
# 260 :  thank great customer service far accidents happen understand hopefully everything works
# 261 :  question crazy boarding procedure does confusion prevent fistfights good seats
# 262 :  opened online applications fall intern positions throughout company apply via
# 263 :  honesty always policy
# 264 :  thanks quick response should call daily wait days
# 265 :  knew correct
# 266 :  briughy aif amp much agcommunity
# 267 :  deals orlando april may
# 268 :  magazine feature desk plants increase productivity luvswa healthbenefitsofplants gardening
# 269 :  new marketing song let know think
# 270 :  prove cuz southwest people even know behind schedule
# 271 :  seeing workers time time going beyond love flying guys thank
# 272 :  bae lost bags clue happened hours
# 273 :  prove
# 274 :  travel agent darrel love field hosting paper airplane contest entertain children awesome see
# 275 :  big kudos staff today dallas love field lifting everyone spirits today delays cancelled flightlations
# 276 :  fun delay nashville las vegas crew gate desk awesome patience luvswa
# 277 :  thinks voucher makes spending hrs plane landing airport took really
# 278 :  never got strip fast stoked special show tonight thx
# 279 :  the problem apologies help results matter proving impossible find anyone interested
# 280 :  fare giving clues route
# 281 :  telling fam vegas
# 282 :  how many tickets left
# 283 :  thank
# 284 :  new mkt strategy average like rest whathappend points devalued again
# 285 :  scavenger hunt locations anything common playing detective trying figure one atl
# 286 :  why
# 287 :  ruined sunday hours delays dia bags wrong airport deliver insult injury
# 288 :  what bring back jackson miss terribly around these airlines horrible
# 289 :  any idea tsa pre check showing next flight tomorrow the number profile
# 290 :  hours degree difference yes please mht mco
# 291 :  sent looking functionality app though one click action
# 292 :  still posted downtown waiting way
# 293 :  like kelsey said really bad spot locals know long takes find parking walking bellagio
# 294 :  people
# 295 :  looks like bellagio good luck people see show vinyl
# 296 :  congrats fans seeing destinationdragons slc next thanks
# 297 :  can pair tickets waiting sports practice live definitely know
# 298 :  love southwest you guys good
# 299 :  destinationdragon tix tonite inconvenience since play scavenger hunt
# 300 :  dang practice hour late flightr today
# 301 :  supposed say boo book booo
# 302 :  vegas days ago miss warm weather
# 303 :  your crew great job keeping everyone informed delays givethemraises
# 304 :  right delayed crabby also allow one family member purchase earlybird check hold rows
# 305 :  really easy locals get strip book
# 306 :  grrrrrr need flight first maybe bday next month
# 307 :  luv new luv television commercials traveled airline last year return trip nyc feltthelove
# 308 :  possible add travel arranged employer upcoming travel retrieve reservation
# 309 :  sent email customer relations calling tomorrow
# 310 :  get priority seating already paid flight
# 311 :  people pre boarded only needed wheel chair plane was not case boarding
# 312 :  possible add companion leg trip
# 313 :  best airline
# 314 :  netneutrality nice see prioritize internet traffic streaming service web sites
# 315 :  poor customer service displayed weekend storm stuck tarmac hours answer
# 316 :  northern california coast
# 317 :  guys general enquires email address please thanks david
# 318 :  watching planes thing
# 319 :  thanks getting paradise safely
# 320 :  feeling frustrated bought wifi onboard load email
# 321 :  continues prove best airlines
# 322 :  just ahead start scavenger hunt today work destinationdragons
# 323 :  let one person board early bird save seats entire party notcool flight
# 324 :  thanks
# 325 :  awesome staff check desk they paper airplane race gift card keep ppl entertained delays
# 326 :  get gin amp tonic
# 327 :  sick joke toyingwithouremotions
# 328 :  please explain every flight dallas going today except
# 329 :  continue airline choice frustrating travel day experienced delays gate changes
# 330 :  got call apologizing personally long waits last week trying rebook flights class act appreciate
# 331 :  serious potential wanna get away commercial debacle but real fire
# 332 :  appreciate response constant changing flight time frustrating say least toughtomakeplans
# 333 :  long delayed boarding get free drink gettingthirsty
# 334 :  done sorry thought already
# 335 :  doesn seem fair bags need fit seats need fit
# 336 :  your terry hero got husband back thru security retrieve cellphone left plane austin terry rock
# 337 :  just wanted change anytime flight leaving phone hold mins phone answers says sorry dice
# 338 :  sincere cancelled flighted flight made drive hours get home
# 339 :  your terry hero got husband back thru security retrieve cellphone left plane austin terry rock
# 340 :  your terry hero got husband back thru security retrieve cellphone austin terry you rock
# 341 :  thanks guys best
# 342 :  stick flying free southwest goes son works wonderful company moms fly free
# 343 :  could control weather las vegas
# 344 :  pretty terrible customer service sat hold min then busy signal then disconnected airlines suck
# 345 :  could please tell way add flight already took place
# 346 :  hooking getting tampa flight cancelled flightled morning grateful businesstrip
# 347 :  love passbook update used day released finally thank
# 348 :  ticket booked cun does arrival time reflect cun est time
# 349 :  yes hope update soon need clothes meeting tomorrow
# 350 :  safety dos don announcer flight midway mdw pittsburgh pit
# 351 :  fair set payed full seat get access full seat
# 352 :  sorry bother hold hours minutes should continue holding call back
# 353 :  another great trip lax las bna thanks much
# 354 :  checkin lame business really last seat broad shoulders haha
# 355 :  yeah somewhere hopefully getting back today just frustrated tweeting
# 356 :  completely understand act god weather relate flightd cancelled flightlation days without reimbursement kind unacceptable
# 357 :  expensive vegas stops late flight june get non stop competition
# 358 :  delayed twice cancelled flighted sent complaint email yet response need explanation pls notsatisfied smh unhappy
# 359 :  got help nice lady phone georgia thank
# 360 :  when flight resume see open schedule
# 361 :  understand weather kids need get home nice kids volunteer work high school please help
# 362 :  thanks quick reply travel lot much lol
# 363 :  that sound hopeful thin device hope right person found time
# 364 :  bag shown luv make phl
# 365 :  regret flying morning support business travelers neverflyvirginforbusiness
# 366 :  thanks motions shortly flight yesterday wonder quickly flight attendants notified
# 367 :  many others know stopping non stop flights atl hartford april
# 368 :  thanks lindsey any idea get stuck denver told listen intercom better
# 369 :  nice touch passbook integration
# 370 :  easy fix let business select actually board board pre boards
# 371 :  companion pass flyer airlines abused every airport
# 372 :  disappointment blatant disregard business select customers becoming problem pushing
# 373 :  need assistance getting extension flight expired
# 374 :  awesome thanks you guys rock
# 375 :  hello remaining credits account refunded back credit card choose lower price flight
# 376 :  expect customer service dallas available
# 377 :  eventually arrived seemed really slow
# 378 :  bags way chicago without help confirmed flights told room screwed
# 379 :  recieved email memphis station hopefully bag
# 380 :  just landed phl row window cover could use luv
# 381 :  thanks adding passbook ability hopefully group passbook tickets future somehow
# 382 :  yep certain flight
# 383 :  arrived late flight pilots got dia time impressive outstanding greatservice allgood
# 384 :  would appreciate thank
# 385 :  never got email confirmation ticket credit card charged phone wait time crazy chat
# 386 :  res chg online app work still hold faster hubby drive airport make change counter fail
# 387 :  can wife points transferred account
# 388 :  friends boston stuck denver her name jane please contact
# 389 :  one find bag need everything next two hours
# 390 :  wasn able sit seat since guy next using worstflightever ideserveareward
# 391 :  glad know flying luv airline tomorrow
# 392 :  yes file report treated rather rudely midway baggage claim now wait days get luggage
# 393 :  would still companion pass ridiculous airline stopped partnering hilton hotels genius
# 394 :  just got companion pass trying add companion flgt get purchase error invalid loyalty member account status help
# 395 :  still heard thing
# 396 :  thank great customer service trying make san antonio staff alerts helpful boo ice
# 397 :  open seating like open marriage much love strangers
# 398 :  hope real life scene movie flight
# 399 :  thanks flights operating cancelled flightled
# 400 :  checked right mark boarding group kids ages amp dnt want split what sld
# 401 :  name jane wanted call
# 402 :  and love flying southwest excellent service take seriously
# 403 :  even better price changed minutes since talked lady still honored cheap
# 404 :  hello flights taking airport noon supposed travel flight san antonio
# 405 :  invite fallow learn activities prevention programs health condom rito family
# 406 :  unveils new flights including ohio
# 407 :  start daily flights washington reagan ftlauderdale aug avgeek
# 408 :  end daily flights washington reagan ftmyers aug avgeek
# 409 :  start xdaily flights orangecounty portland aug avgeek
# 410 :  start daily flights columbus oakland aug avgeek
# 411 :  start xdaily flights columbus boston aug avgeek
# 412 :  password reset email incredibly slow arrive today checked spam folder web site says minutes
# 413 :  thank may already responded uxzj
# 414 :  terrible service three airports hours glad care kind need home sellmypointssoon
# 415 :  thanks confirmation number dmed appreciate help
# 416 :  hold min estimated answer time any help
# 417 :  going start charging consistent body pat downs starting feel like piece meat punishedforflying
# 418 :  what wait times customer service line tried fri min
# 419 :  can equip flamethrowers snow plow
# 420 :  unveils new routes including ohio via
# 421 :  flight delayed hours another week another delayed flight
# 422 :  thanks linking passbook might old news first flight
# 423 :  realize clothes hotel suggestions
# 424 :  may want direct people tok
# 425 :  bag possession clothes bag
# 426 :  really going let get best
# 427 :  please get back airtran credit vnmb call told never get email call back
# 428 :  link site displays delays cancelled flightations flights
# 429 :  pleaseeee resume direct flights fll phl want fly anyone else
# 430 :  show destination clothes suitcase nakedmeetings awkward
# 431 :  are discounts every tuesday cause leaving fron birmingham airport san fran next week march sometime
# 432 :  anyone realize banning peanuts flight due allergic person ignores nut oil amp dust previous flights
# 433 :  customer service rude bothered calls has idea going sighed heavily phone unbelievable
# 434 :  hrs late flightr human interaction ended ing completely new flight last flight sell
# 435 :  loses baggage day ago still idea interest finding all items new job bag unacceptable
# 436 :  how get companion pass thanks lin
# 437 :  just sent thanks attentiveness matter
# 438 :  fixing wifi flight working series plane like old plane
# 439 :  mdw san like flights watching free works hardly access websites including
# 440 :  kids mission trip lasalle stranded orlando area get back bos pvd till wednesday
# 441 :  pls help baby hannah get life saving surgeries requires she needs help pls donate
# 442 :  almost gate please wait seconds
# 443 :  paid early bird boarding got said lady well system dead she understand
# 444 :  all flights booked they saying wait tomorrow
# 445 :  arrangements reimburse rental get
# 446 :  one planes thanks taking arizona
# 447 :  gate agent gave wrong departure info caused miss flight stand nothappy
# 448 :  thanks
# 449 :  bag lost according rep even know please help
# 450 :  sent details thanks
# 451 :  thank confirmation maybe people flight directional dislexia
# 452 :  got email confirmation wifi purchase recent flight trouble never flown ever concerned scam
# 518 :  hour half came back damaged not happy
# 519 :  long take rapid rewards points credited account
# 520 :  customer service rather inconsistent information
# 521 :  pulling runway making new friends seat mates thanks response
# 522 :  make tru find space flights this customer service bad
# 523 :  delay pay ticket you boarded flight early last board now middle seat wasted
# 524 :  first good idea thatthis would happen cancelled flight earlier amateurish plan
# 525 :  disappointed handling tonight cancelled flighted dallas flight not cancelled flighted contingencies
# 526 :  southwest still best airline around just hate baggage room runs checked bag headphones
# 527 :  please start flying huntsville never fly american airlines
# 528 :  flight arrives following flight
# 529 :  care mighty dollar
# 530 :  child traveling cross country turning march cont
# 531 :  get one
# 532 :  retiring hubby wedding anniversary year companion pass please
# 533 :  beautiful view flying san jose evening
# 534 :  thank swa shannon miracle worker awesome
# 535 :  but expect help our flt canx last minute weather flew home weatherless
# 536 :  want new orleans houston see dad anderson help
# 537 :  yes please
# 538 :  changed flight louis thanks reply though
# 539 :  flying getting old
# 540 :  really offer sweeps link going work
# 541 :  have companion pass years wife use time thanks southwest making travel easy
# 542 :  why longer change trips companion online been years get message done online
# 543 :  wifi slow totally precludes working web will not book swa business travel wish lit fire
# 544 :  yes please son lives
# 545 :  companion pass please
# 546 :  constantly providing wonderful views service southwestluv
# 547 :  everyone deserves red carpet destroy luggage amp give voucher like want fly
# 548 :  staff overall awful multiple airports would switched airlines another flight available
# 549 :  lol already card member well lol enjoy flying guys
# 550 :  anniversary april still sweethearts companions lifetime sons families love
# 551 :  well need something aim
# 552 :  yes please how get companion pass
# 553 :  flight paid wifi load website functionally except live streaming unacceptable
# 554 :  gimme
# 555 :  flights still going dal
# 556 :  you inspired start airline combat weak ass airline sick shit
# 557 :  service aruba permanently discontinued august
# 558 :  yes please
# 559 :  miss mine terribly anniversary would amazing would mean luv air dontmakemebeg
# 560 :  heart status sure would nice though
# 561 :  redcarpet southwest companion pass would great
# 562 :  would love great deal bwi las memorial day weekend aka bday weekend
# 563 :  want one
# 564 :  everyones flights cancelled flightled today deserve
# 565 :  companion pass because everyone deserves redcarpet treatment even mom
# 566 :  sign
# 567 :  would love redcarpet treatment
# 568 :  get companion pass
# 569 :  tell secrets flying high redcarpet
# 570 :  that would brighter stars combined red carpet tonight
# 571 :  how auto check holders come
# 572 :  got mine just time wife anniversary
# 573 :  love companion pass qualified year hollymais
# 574 :  mines
# 575 :  continue amazed amazing customer service thank swa
# 576 :  one obtain companion pass
# 577 :  yes please
# 578 :  subscribe please
# 579 :  sign
# 580 :  got mine
# 581 :  wifi worst investment ever made
# 582 :  can get help cancelled flighting flight reservation
# 583 :  sitting newark flight cancelled flightled apparent reason all told sorry hrs waiting
# 584 :  followed awaiting
# 585 :  dont atlanta san fransisco present sale like last sale looking return tickets
# 586 :  bothered help lost luggage not single helpful employee owner found bwi
# 587 :  seriously four delays only takes minutes get vegas amp connecting flight ridiculous
# 588 :  get shit together owe bag
# 589 :  requested boarding pass texted still received
# 590 :  gave one try figured could get flight right nope delayed seems every time
# 591 :  gonna ignore fasten seatbelt sign want see man enough anything
# 592 :  huge fan give much business please fix damn wifi
# 593 :  got next time know paying extra make line
# 594 :  understand air delays control terrible telephone support apps online access work
# 595 :  flying south southwest sjc sna tiday
# 596 :  thanks connection thru nashville boarding pass get dallas gate boarding min flt get end group
# 597 :  weather keeps slowing not fault this time southwest flight mine late flight complain
# 598 :  thanks
# 599 :  still planing flights dal trying fly tomorrow lax
# 600 :  board thanks you guys moved standby holding boarding pass since yesterday
# 601 :  beautiful fleet what perfect evening fly
# 602 :  leave bur ten minutes late flight arrive sjc minute supposed impressed gettingbetter
# 603 :  lost promise ring gave flight sfo sna infinity silver band ring please help
# 604 :  two delayed flights row neither one explained
# 605 :  sleeping floor like homeless delayed flights equipment working job get
# 606 :  guys stop service denver horrible get stuck every time almost hrs
# 607 :  thanks only minor delay big deal appreciate concern though boarding you amazing service
# 608 :  traveling year old thursday need correct
# 609 :  how dallas incoming looking scheduled fly wondering stuck louis instead
# 610 :  had unpleasant experience phone one agents cancelled flightled flight name amp agent
# 611 :  wifi angering slowness
# 612 :  thank
# 613 :  gate long time gonna miss connection mdw ack
# 614 :  tweeted several times last week flight info storm always timely tweet back thx
# 615 :  sort arriving day late flight incur overnight costs connecting city not cool
# 616 :  promised rooms wednesday wentook hotel charged per room pink paper needed white
# 617 :  sent
# 618 :  rules probably apply times sometimes shouldhaveflownjetblue
# 619 :  hold music sounds like super mario bros gameboy color
# 620 :  props las employees working gate because opposed flying las future
# 621 :  baggage delivery bwi delayed unnecessarily chaotic disappointing long trip from frequent traveler
# 622 :  carriers flying way past cancelled flightlation got passengers much late flightr
# 623 :  extremely frustrating travel experience denver instead landing sea saturday monday afternoon
# 624 :  calling someone monday customer relations very disappointed treated customer service
# 625 :  complimentary hotel vouchers night crappiest hotel ever wish worst enemy
# 626 :  worst air line ever compassion handicapped
# 627 :  two free flights promo coming back looking premiere card might hold another option
# 628 :  bunch liars cancelled flightled flight rebooked four days late flightr
# 629 :  done
# 630 :  currently rebooked thru dallas hear expecting ice storm sigh strandednyc
# 631 :  check grader school science fair project she loves flying southwest airlines
# 632 :  ohk thank you inexpensive airfares southwest travel around
# 633 :  golf bag broken flight took what process damage reimbursement
# 634 :  ridiculous want charge change flights even multiple seats available flight needed
# 635 :  mad love nyc
# 636 :  thanks cancelled flighting flight bos stranded den til wed night the never fly southwest
# 637 :  trying find airfare family your prices ridiculous almost notmadeofmoney
# 638 :  fav
# 639 :  flight delayed till tomorrow curse weather
# 640 :  lucky forced good deed get smashed huge ppl exit row thank god tiny
# 641 :  wish allowed access site awards tracking
# 642 :  got back mins ago went hrs appreciate support voucher essentials
# 643 :  party hotlanta
# 644 :  btw completely unable buy wifi flight using galaxy couldn zoom scroll touch buy
# 645 :  party atl terminal letitgo
# 646 :  heard rumor flight cancelled flightled true
# 647 :  hosting party terminal atlanta peanutsonaplatter
# 648 :  just watched crew flight help elderly lady plane firstclass
# 649 :  still know skis cannot get call back bag svc airport left several msgs
# 650 :  wife flight dal got cancelled flightled what find options get back home phx dal
# 651 :  thanks response flight time passed rebooked
# 652 :  sorry hear wifi connection dani please conf help thanks
# 653 :  guys rule thank
# 654 :  good back see several weeks
# 655 :  boooo don like airlines
# 656 :  stewardess really funny now could get gent next use headphones would perfect flight
# 657 :  find way cancelled flight flight
# 658 :  check see flight nyc expected delayed cancelled flightled tuesday
# 659 :  thx note flight cancelled flightled today booked another carrier
# 660 :  could get phone call customer service rep get issue resolved
# 661 :  think great people working
# 662 :  way flying denver today must airline cancelled flighting delaying flights flyswa denverairport
# 663 :  first pilot first officer galley flight
# 664 :  updates flights getting cancelled flighted dal connecting flight hope delay due weather
# 665 :  flight got cancelled flightled hrs takeoff customer service been hold minutes
# 666 :  flight continues vegas stop don upset stowaway
# 667 :  waiting half hour checked baggage delivered updates ground crew
# 668 :  promotion mail today vegas jamaica defective link vegas sweepstakes times error
# 669 :  safety back dallas
# 670 :  like said could reach anyone company rent car chalk whole thing loss
# 671 :  guys amazing sending people meet imagine dragons destinationdragons
# 672 :  btw weather delay beautiful weather sunny california nolove noexcuses cali
# 673 :  frequent traveler never treated coldly amp airline offer nothing flight cancelled flightled nolove
# 674 :  neveryamind paid flight new bag easy business class customers right
# 675 :  baggage motto cover small tear ripped seam snow soaked busted zippers sorry
# 676 :  totally ruined birthday weekend cancelled flighting flights reason offer points drink transport nolove cali
# 677 :  what happened customer service cancelled flightled flights days amp uninformed unapologetic staff nolove cali
# 678 :  check head plane dynamite placed onto
# 679 :  maybe comped quietly accepted delays cancelled flightations instead irate less issues justsaying
# 680 :  for past yrs earned list status thru promo fly rnd trips months how get option loyal
# 681 :  nothing ruined wet just frustrating traveling hours change clean clothes
# 682 :  yeah happens the phx airport extra long waits spring long something locals know tourist fyi
# 683 :  tried hrs contact twitter phone email reply hrs late flightr respond could point
# 684 :  arkansas gov plans sign governor legalizes discrimination lgbt can lend voice state boycott
# 685 :  rapid awards member points apply taken round trip
# 686 :  line mile long sky harbor morning your staff courteous expeditious thank onechildfourbags
# 687 :  never awful customer service conflicting service outrageous
# 688 :  just realized wrong departure date thanks making changes easy
# 689 :  also southwest specials like one running
# 690 :  last week flew dal lax you got almost hour early thank you
# 691 :  daytona available free
# 692 :  flying flight tonight pbi boarding position overbooked really want bumped
# 693 :  after hour frustrated hang
# 694 :  thanks terrible service stranded mdw days amp find confirmation rebooked flight mke
# 695 :  fyi link baggage incident email redirects mobile the link auto changes mobile desktop works fine
# 696 :  say customer service consistently best
# 697 :  tfw appreciate tweet back unexpected
# 698 :  need cancelled flight please check
# 699 :  mom says hire staff accommodate audience you could learn lots she
# 700 :  although wait long due weather scheduling phone call super rep solved issue thank
# 701 :  starting routes hawaii canada
# 702 :  flying flight tonight pbi boarding position flight overbooked have funeral attend
# 703 :  never able talk someone buy another new ticket will calling shortly refund
# 704 :  tfw spent total hrs mins holding cell battery died finally made arrangements kind rep
# 705 :  better
# 706 :  mins hold finally hung ridiculous wait times can assist cancelled flighting reservation
# 707 :  make world better place visit elderly relative
# 708 :  what best credit card use open get miles
# 709 :  woman gets plane holds seats bulkhead friends boarding passes paid earlybird thx
# 710 :  grouchy flight complimentarybeveragesneeded
# 711 :  plane switch meant back plane disappointed
# 712 :  let oversold earlybirdmeansnothing
# 713 :  clearly care troubles yday thought share bags took min came back absolutely drenched
# 714 :  follow quick
# 715 :  help
# 2259 :  thank response how got getting points onto rewards account
# 2260 :  tried let says following
# 2261 :  chances flight leaving bna tomorrow lga
# 2262 :  got squared away thank man inside help
# 2263 :  please number lodge formal complaints thx
# 2264 :  just sent details
# 2265 :  good thing noticed routed total passengers impossible triple connection well
# 2266 :  gate agent routed impossible itinerary find new airline get home super bummed
# 2267 :  auto callbacks wait hold
# 2268 :  received email reso email associated swa account info sister fraud please
# 2269 :  thank
# 2270 :  your onboard wifi bad taking minutes send tweet working table disappointed
# 2271 :  another great flight amp crew las vegas chicago thanks
# 2272 :  recommend upgrading ivr using call back email texting know caller
# 2273 :  entire flight luggage missing dca over hour nobody knows anything
# 2274 :  get hold called twice kicked calls phonedied alistpreferred
# 2275 :  only airline flying bna today
# 2276 :  finally got thanks
# 2277 :  spent minutes counting hold today after first minutes gave trying amp min
# 2278 :  ive airline everyone else great soured whole experience hope next time
# 2279 :  thanks got put flight tomorrow don much faith get ground tomorrow though
# 2280 :  think shot can find flight arrives business san thu really want
# 2281 :  woman working counter philly needs fired due bad weather along passengers
# 2282 :  earlier reflight booking problems flight didn get screencap said unspecified error call swa
# 2283 :  buying early bird pointless you moved diff flight first one delayed lost boarding position
# 2284 :  problem website tried making changes app site got unspecified errors
# 2285 :  love southwest payton taylor
# 2286 :  rdu flights expected afternoon tonight
# 2287 :  super disappointed today first time stress book flight another airline airport
# 2288 :  put next flight available tomorrow morning any idea bna open morning flight
# 2289 :  hey swair tortured boarding flight due one gate agent board assisted folks one time
# 2290 :  understand delay stuck plane longer flight unacceptable
# 2291 :  absolutely where send
# 2292 :  worries you best already cancelled flighted biz trip still luv
# 2293 :  years flying never pissed many incidents one flight
# 2294 :  heard apology times mins hold now flying another airport different time delayed again
# 2295 :  happily but need follow order
# 2296 :  make sure tell everyone know around horrible experience also post business page
# 2297 :  currently bringing year old bathroom rushed flight attendant
# 2298 :  worries got thru eventually curious best luck dealing weather
# 2299 :  terribly inspired call customer service future
# 2300 :  also said even book flight they put hold amp someone else
# 2301 :  person talked anything normally available online charge part
# 2302 :  someone help set callback today
# 2303 :  cancelled flightlations link rebook like initial storm issues
# 2304 :  really guidance call via phone back logged could done online minutes
# 2305 :  rebook flight board bham
# 2306 :  please send number call talk person put hold
# 2307 :  flt buf mco conf fgkxv please also look reimburse car count cancelled flight
# 2308 :  almost hours hold need cancelled flight flight get refund other airlines operating
# 2309 :  you need accommodating loyal customers not happy
# 2310 :  yes thank oct oct
# 2311 :  eventually get flight cancelled flightled decided drive gave holding process refund
# 2312 :  already rebooked tomorrow fingers crossed
# 2313 :  followed
# 2314 :  worst customer service terrible attitudes care big storm your employees need attitude adjustment
# 2315 :  could send
# 2316 :  following think follow
# 2317 :  flight cancelled flightled bna reschedule travel funds put back account future use
# 2318 :  kidding needed help yesterday landed waiting connection never fly southwest
# 2319 :  bags back ding
# 2320 :  yeah bruh bool niggaz need hire workers something cause next time imma forced disrespect
# 2321 :  always fly loyalrrmember
# 2322 :  thank someone finally answered able change flight cancelled flighted ice thank response
# 2323 :  trying add dog flight get
# 2324 :  need request refund flight cancelled flightled morning due weather
# 2325 :  thanks ton
# 2394 :  can link article says routes times routes likely like tul dal none
# 2395 :  southwest mobile boarding passes available ios passbook
# 2396 :  cancelled flightled flight bna today been hold hour frustrated
# 2397 :  beautiful thanks ton
# 2398 :  tried rebook online says pay difference price please help
# 2399 :  showing flight delayed would boarding pass still good seat given away
# 2400 :  update flight online cancelled flighted twice already going hour hold
# 2401 :  guys real hold hours including one hangup please someone reach get back
# 2402 :  kind early idea dates first week sept come available
# 2403 :  last times arrived gate blocked slow depart plane leading min delays
# 2404 :  hold minutes cancelled flightled flight still talked anyone flight soon what gives
# 2405 :  hoping answer phone today
# 2406 :  husband hold hrs got disconnected new wait min can confirm res due fact booked line nuts
# 2407 :  thanks yall expect operational tomorrow nashville
# 2408 :  guys jacked prices after said prices going lowered smh
# 2409 :  hold hours hung cancelled flightled flights running daycare kids trapped home
# 2410 :  really unhelpful why rebook online
# 2411 :  allows passengers harass gate agents mistakefurious nothing amp scared
# 2412 :  flight cancelled flightled let rebook online wait time phone long please help
# 2413 :  guys got something inability check online international flight
# 2414 :  temporary site glitch longer offering flights grr geg feb can find online
# 2415 :  answer phones horribleservice neveragain frustrated answerthephone
# 2416 :  stuck sju several hours one answering really tough luv response bad
# 2417 :  nice work update
# 2418 :  guys are hour phone hold volume short staffing
# 2419 :  cool bags take bit longer dont give baggage blue balls turn carousel tell coming

# %%
print(single_airline.airline_sentiment.value_counts())
# Out:
# negative    1186
# neutral      664
# positive     570
# Name: airline_sentiment, dtype: int64

# %% [markdown]
# ## 5 most frequent words (not counting stopwords) in positive and Negative tweets

# %% [markdown]
# Here,i just created a new column with a list of tokenized words for each tweet text

# %%
single_airline['text_split'] = single_airline['text'].apply(lambda x: x.split(" "))

# %% [markdown]
# Now i have created a corpus for positive and negative tweet sentiment Now that i have tokenized the tweet text, i created lists containing words in all the positive and negative tweet text. So that positive tweet words and negative tweet words can be differentiated. For this, i am using use itertools to chain together all the positive and negative tweet text in single lists. The below link is followed
#
# https://datascienceparichay.com/article/python-frequency-of-each-word-in-string/?fbclid=IwAR2zR3WYsLuFFlNLv7V6S9niWdoOnCXzeg3TxSp6FloqH97ufFV12pxYIx4

# %%
import itertools
# positive tweets
positive_reviews = single_airline[single_airline['airline_sentiment']=='positive']['text_split']
print("Total positive tweets: ", len(positive_reviews))
positive_reviews_words = list(itertools.chain(*positive_reviews))
print("Total words in positive tweets:", len(positive_reviews_words))
# negative negatives
negative_reviews = single_airline[single_airline['airline_sentiment']=='negative']['text_split']
print("Total negative tweets: ", len(negative_reviews))
negative_reviews_words = list(itertools.chain(*negative_reviews))
print("Total words in negative tweets:", len(negative_reviews_words))
# Out:
# Total positive tweets:  570
# Total words in positive tweets: 4116
# Total negative tweets:  1186
# Total words in negative tweets: 11325

# %% [markdown]
# Now i have estimated the word frequency in the corpus Then i have figued out the frequency of each word in the positive and the negative corpus. For this, i am using collections. As collection has Count function which is helpful.Counter that returns an object which is essentially a dictionary with word to frequency mappings. It is useful tool for counting frequncy of word from corpus thats why i am using this.

# %%
import collections
positive_words_frequency = collections.Counter(positive_reviews_words)

negative_words_frequency = collections.Counter(negative_reviews_words)

# %% [markdown]
# I have created a dataframe each for the top 5 most frequent words in positive and negative corpuses. It helps me to plot a horizontal bar chart of the 5 most frequent words in both positive and negative the corpuses. With this dataframe it is easier to visualize frequent word.

# %%
positive_freq_words_df = pd.DataFrame(positive_words_frequency.most_common(5),
                                     columns=["Word", "Frequency"])
print("5 most  frequent words in Positive tweet:\n")
print(positive_freq_words_df)
# Out:
# 5 most  frequent words in Positive tweet:
#
#      Word  Frequency
# 0  thanks        126
# 1   thank        117
# 2  flight         92
# 3   great         57
# 4    love         48

# %%
negative_freq_words_df = pd.DataFrame(negative_words_frequency.most_common(5),
                                     columns=["Word", "Frequency"])
print("5 most  frequent words in Negative tweet:\n")
print(negative_freq_words_df)
# Out:
# 5 most  frequent words in Negative tweet:
#
#         Word  Frequency
# 0     flight        408
# 1  cancelled        203
# 2       hold        151
# 3        get        136
# 4  flightled         98

# %% [markdown]
# ## 5 most frequent words (not counting stopwords) in each identified cluster

# %% [markdown]
# I have created an instance of the CountVectorizer class and then Call the fit_transform() function in order to learn a vocabulary from one or more documents and then encode each as a vector. I set max features to 1000 so only the top 1000 most frequest words are used and then removed stop words. Here i define and fit clustering model with the ideal number of clusters based on the elbow graph (showed in clustering tool). Then a new column named cluster was created for the predicted value of cluster sothat i can get the cluster words easily from dataframe. Then i set a for loop according to the number of cluster. Rest of the process is similar for counting most frequent word in cluster as described above for counting positive and negative most frequent word.

# %%
from sklearn.feature_extraction.text import CountVectorizer
num_clusters=6
bow_vectorizer = CountVectorizer(max_features=1000, stop_words = 'english')
tweet_matrix = bow_vectorizer.fit_transform(X)
kmeans = KMeans(n_clusters=num_clusters, max_iter=1000)
kmeans.fit_predict(tweet_matrix)

single_airline['cluster'] = kmeans.fit_predict(tweet_matrix) # creating a new column of cluster

# %%
for i in range(num_clusters):
    cluster_one= single_airline[single_airline['cluster']==i]['text_split']
   
    cluster_one_words = list(itertools.chain(*cluster_one))
     
    cluster_one_words_frequency = collections.Counter(cluster_one_words)
    
    
    cluster_one_freq_words_df = pd.DataFrame(cluster_one_words_frequency.most_common(5),
                                     columns=["Word", "Frequency"])
    print("Cluster", i ,":5 most frequent words\n")
    print(cluster_one_freq_words_df)
    print("\n")
# Out:
# Cluster 0 :5 most frequent words
#
#       Word  Frequency
# 0      get        144
# 1   thanks        139
# 2    thank        119
# 3  flights        101
# 4     help         86
#
#
# Cluster 1 :5 most frequent words
#
#      Word  Frequency
# 0  flight        395
# 1     get         42
# 2    late         36
# 3    time         35
# 4  thanks         33
#
#
# Cluster 2 :5 most frequent words
#
#         Word  Frequency
# 0     flight        203
# 1  cancelled        195
# 2  flightled        106
# 3       hold         41
# 4   flighted         37
#
#
# Cluster 3 :5 most frequent words
#
#         Word  Frequency
# 0    service        122
# 1   customer        112
# 2        amp         14
# 3       hold         14
# 4  relations         11
#
#
# Cluster 4 :5 most frequent words
#
#         Word  Frequency
# 0       date          2
# 1      first          1
# 2       time          1
# 3      flyer          1
# 4  scheduled          1
#
#
# Cluster 5 :5 most frequent words
#
#       Word  Frequency
# 0     hold        100
# 1     hour         34
# 2    hours         21
# 3  minutes         19
# 4   flight         17
